# %% [markdown]
# ### Importing Libraries

# %%
import os
import numpy as np #alias
import pandas as pd #alias
import seaborn as sns #alias
import matplotlib.pyplot as plt #alias

# %%
CURRENT_DIR = os.getcwd()
print(f"CURRENT DIRECTORY : {CURRENT_DIR}")
# Out:
# CURRENT DIRECTORY : c:\Users\User\Desktop\FOML\week 01

# %% [markdown]
# ### Basic Information

# %%
churn_data = pd.read_csv('data/raw/ChurnModelling.csv')
churn_data.head(5)
# Out:
#    RowNumber  CustomerId Firstname  Lastname  CreditScore Geography  Gender  \
# 0          1    15634602     Grace  Williams          619    France  Female
# 1          2    15647311     David     Jones          608     Spain  Female
# 2          3    15619304      Hank  Williams          502    France  Female
# 3          4    15701354       Eva    Taylor          699    France  Female
# 4          5    15737888     Grace    Miller          850     Spain  Female
#
#     Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0  42.0       2       0.00              1          1               1
# 1  41.0       1   83807.86              1          0               1
# 2  42.0       8  159660.80              3          1               0
# 3   NaN       1       0.00              2          0               0
# 4  43.0       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# ...

# %%
churn_data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Firstname', 'Lastname', 'CreditScore',
#        'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
#        'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='str')

# %%
churn_data.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Firstname              str
# Lastname               str
# CreditScore          int64
# Geography              str
# Gender                 str
# Age                float64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
churn_data.rpow
# Out:
# <bound method DataFrame.rpow of       RowNumber  CustomerId Firstname  Lastname  CreditScore Geography  \
# 0             1    15634602     Grace  Williams          619    France
# 1             2    15647311     David     Jones          608     Spain
# 2             3    15619304      Hank  Williams          502    France
# 3             4    15701354       Eva    Taylor          699    France
# 4             5    15737888     Grace    Miller          850     Spain
# ...         ...         ...       ...       ...          ...       ...
# 9995       9996    15606229     Grace    Garcia          771    France
# 9996       9997    15569892      Jack    Garcia          516    France
# 9997       9998    15584532     Carol   Johnson          709    France
# 9998       9999    15682355      Jack    Garcia          772   Germany
# 9999      10000    15628319       Eva    Garcia          792    France
#
#       Gender   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# ...

# %%
churn_data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore          Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  9400.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800    38.912128      5.012800
# std     2886.89568  7.193619e+04     96.653299    10.512778      2.892174
# min        1.00000  1.556570e+07    350.000000    18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000    32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000    37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000    44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000    92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# ### plot distribution of 'Exited' column

# %%
churn_data['Exited'] # pandas series
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
churn_data['Exited'].values
# Out:
# array([1, 0, 1, ..., 1, 1, 0], shape=(10000,))

# %%
balance = churn_data['Exited'].value_counts()
balance
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
balance.plot(
    kind='pie',
    figsize=(8, 6),
)
# Out:
# <Axes: >
