# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import (
                            mean_squared_error, mean_absolute_error, r2_score,
                            accuracy_score, precision_score, recall_score, f1_score,
                            roc_curve, auc, confusion_matrix, log_loss
                            )

# %%
data = pd.read_csv('zuu crew scores.csv')
data['passed'] = (data['CapstoneScore'] >= 50).astype(int)
data = data[data['CourseName'] == 'Foundations of ML']
del data['MemberName'], data['CourseName']
data.head()
# Out:
#    EducationLevel  Attendance  TotalHours  AssignmentsCompleted  \
# 0               3        79.9        43.7                     2
# 1               2        76.8        95.6                     6
# 2               3        96.6        75.9                     8
# 4               2        83.2        24.0                     6
# 7               3        86.5        88.0                     5
#
#    HackathonParticipation  GitHubScore  PeerReviewScore  CapstoneScore  passed
# 0                       0         62.8              5.0           45.3       0
# 1                       0         87.4              2.7           78.8       1
# 2                       0         98.4              2.8           65.4       1
# 4                       0         41.8              4.2           40.1       0
# 7                       0         23.9              1.3           68.2       1

# %% [markdown]
# ### Regression

# %%
X = data.drop(columns=['CapstoneScore', 'passed'])
Y = data['CapstoneScore']

# %%
def l2_linear_regression(
                        X, Y, 
                        lr = 1e-4, 
                        lambda_reg = 1e-4,
                        iterations = 1000
                        ):
    n, m = X.shape 
    w = np.random.randn(m)
    b0 = 0

    loss_arr = []

    ''' 
    w = betas means weights
    '''

    for epoch in range(iterations):
        # Forward pass
        yhat = b0 + np.dot(X, w)
        resid = Y - yhat # residual means error terms
        
        # Compute gradients with L2 regularization
        grad_w = -np.dot(X.T, resid) / n + lambda_reg * w # dw = grad_w
        grad_b = -np.mean(resid) # db = grad_b
        
        # Standard gradient descent update
        w = w - lr * grad_w
        b0 = b0 - lr * grad_b
        
        # Compute total loss (MSE + L2 penalty)
        mse_loss = 0.5 * np.mean(resid**2)
        l2_panelty = lambda_reg * np.dot(w, w)
        loss = mse_loss + l2_panelty
        loss_arr.append(loss)

    return w, b0, loss_arr

# %%
w1, b0_1, loss_arr_1 = l2_linear_regression(X, Y)

print(f"best w : {w1}")
print(f"best b0 : {b0_1}")
# Out:
# best w : [ 0.24369386  0.23129558  0.62859159 -0.11126416 -0.5632965   0.03311087
#  -0.04234697]
# best b0 : -0.005117166134475044

# %%
w2, b0_2, loss_arr_2 = l2_linear_regression(X, Y, lambda_reg=1)

print(f"best w : {w1}")
print(f"best b0 : {b0_2}")
# Out:
# best w : [ 0.24369386  0.23129558  0.62859159 -0.11126416 -0.5632965   0.03311087
#  -0.04234697]
# best b0 : 0.022482674091095684

# %%
fig, ax = plt.subplots(1, 2, figsize = (20,5))
ax[0].plot(loss_arr_1)
ax[0].set_title('lambda_reg = 1e-4')

ax[1].plot(loss_arr_2)
ax[1].set_title('lambda_reg = 1')
plt.xlabel("n iterations")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')

# %%
Yhat_1 = b0_1 + np.dot(X, w1)
Yhat_2 = b0_2 + np.dot(X, w2)

# %%
mse_l2_1 = mean_squared_error(Y, Yhat_1)
mae_l2_1 = mean_absolute_error(Y, Yhat_1)
r2_l2_1 = r2_score(Y, Yhat_1)

mse_l2_2 = mean_squared_error(Y, Yhat_2)
mae_l2_2 = mean_absolute_error(Y, Yhat_2)
r2_l2_2 = r2_score(Y, Yhat_2)

# %%
print(f"MSE L2 | lambda_reg = 1e-4 : {mse_l2_1}")
print(f"MAE L2 | lambda_reg = 1e-4 : {mae_l2_1}")
print(f"R2 L2 | lambda_reg = 1e-4 : {r2_l2_1}")

print('\n')
print(f"MSE L2 | lambda_reg = 1 : {mse_l2_2}")
print(f"MAE L2 | lambda_reg = 1 : {mae_l2_2}")
print(f"R2 L2 | lambda_reg = 1 : {r2_l2_2}")
# Out:
# MSE L2 | lambda_reg = 1e-4 : 26.941512934861716
# MAE L2 | lambda_reg = 1e-4 : 3.9289773048719403
# R2 L2 | lambda_reg = 1e-4 : 0.9057095011023203
#
#
# MSE L2 | lambda_reg = 1 : 29.253108707564007
# MAE L2 | lambda_reg = 1 : 4.219896722915824
# R2 L2 | lambda_reg = 1 : 0.8976193274292661

# %% [markdown]
# ### Classification

# %%
X = data.drop(columns=['CapstoneScore', 'passed'])
Y = data['passed']

# %%
def sigmoid(z):
    """
    Numerically stable sigmoid function.
    
    Args:
        z: Input array or scalar
        
    Returns:
        Sigmoid of z
    """
    return 1.0 / (1.0 + np.exp(-z))

# %%
def l2_log_regression(
                        X, Y, 
                        lr = 1e-4, 
                        lambda_reg = 1e-4,
                        iterations = 1000
                        ):
    n, m = X.shape 
    w = np.random.randn(m)
    b0 = 0

    loss_arr = []

    ''' 
    w = betas means weights
    '''

    for epoch in range(iterations):
        # Forward pass
        z = b0 + np.dot(X, w)
        Yhat = sigmoid(z)
        resid = Y - Yhat # residual means error terms
        
        # Compute gradients with L2 regularization
        grad_w = -np.dot(X.T, resid) / n + lambda_reg * w # dw = grad_w
        grad_b = -np.mean(resid) # db = grad_b
        
        # Standard gradient descent update
        w = w - lr * grad_w
        b0 = b0 - lr * grad_b
        
        # Compute total loss (BCE + L2 penalty)
        bce_loss = log_loss(Y, Yhat, labels=[0, 1])
        l2_panelty = lambda_reg * np.dot(w, w)
        loss = bce_loss + l2_panelty
        loss_arr.append(loss)

    return w, b0, loss_arr

# %%
w1, b0_1, loss_arr_1 = l2_log_regression(X, Y)

print(f"best w : {w1}")
print(f"best b0 : {b0_1}")
# Out:
# best w : [ 1.31235888  0.36950663  0.72795419  0.49592907  0.98530984 -0.97614213
#  -0.63909844]
# best b0 : -0.017923776571554997

# %%
w2, b0_2, loss_arr_2 = l2_log_regression(X, Y, lambda_reg=1)

print(f"best w : {w1}")
print(f"best b0 : {b0_2}")
# Out:
# best w : [ 1.31235888  0.36950663  0.72795419  0.49592907  0.98530984 -0.97614213
#  -0.63909844]
# best b0 : 0.006826039877764955

# %%
fig, ax = plt.subplots(1, 2, figsize = (20,5))
ax[0].plot(loss_arr_1)
ax[0].set_title('lambda_reg = 1e-4')

ax[1].plot(loss_arr_2)
ax[1].set_title('lambda_reg = 1')
plt.xlabel("n iterations")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')

# %%
Yhat_1 = sigmoid(b0_1 + np.dot(X, w1))
Yhat_2 = sigmoid(b0_2 + np.dot(X, w2))

# %%
Yhat_1 = Yhat_1 > 0.5
Yhat_2 = Yhat_2 > 0.5

# %%
accuracy_1 = accuracy_score(Y, Yhat_1)
precision_1 = precision_score(Y, Yhat_1)
recall_1 = recall_score(Y, Yhat_1)
f1_1 = f1_score(Y, Yhat_1)

accuracy_2 = accuracy_score(Y, Yhat_2)
precision_2 = precision_score(Y, Yhat_2)
recall_2 = recall_score(Y, Yhat_2)
f1_2 = f1_score(Y, Yhat_2)

# %%
print(f"Accuracy | lambda_reg = 1e-4 : {accuracy_1}")
print(f"Precisiom | lambda_reg = 1e-4 : {precision_1}")
print(f"Recall | lambda_reg = 1e-4 : {recall_1}")
print(f"F1 Score | lambda_reg = 1e-4 : {f1_1}")

print("\n")
print(f"Accuracy | lambda_reg = 1 : {accuracy_2}")
print(f"Precisiom | lambda_reg = 1 : {precision_2}")
print(f"Recall | lambda_reg = 1 : {recall_2}")
print(f"F1 Score | lambda_reg = 1 : {f1_2}")
# Out:
# Accuracy | lambda_reg = 1e-4 : 0.6388888888888888
# Precisiom | lambda_reg = 1e-4 : 0.6666666666666666
# Recall | lambda_reg = 1e-4 : 0.7619047619047619
# F1 Score | lambda_reg = 1e-4 : 0.7111111111111111
#
#
# Accuracy | lambda_reg = 1 : 0.7777777777777778
# Precisiom | lambda_reg = 1 : 0.7954545454545454
# Recall | lambda_reg = 1 : 0.8333333333333334
# F1 Score | lambda_reg = 1 : 0.813953488372093
